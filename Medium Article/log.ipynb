# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import norm, skew

# %%
plt.figure(figsize=(12, 8))
x = np.linspace(start=1, stop=1000)
y = np.log(x)
plt.plot(x, y)
